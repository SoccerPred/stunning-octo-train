# %% [markdown]
# ## Competitions

# %%
import pandas as pd
from urllib.request import urlopen
import json
import numpy as np

# %% [markdown]
# # History

# %% [markdown]
# Get friendlies data

# %%
with urlopen('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=362') as response:
    his = response.read()
    history = json.loads(his)
history.get('data')['match']
# Out:
# [{'competition_name': 'FIFA World Cup',
#   'league_id': 793,
#   'date': '2018-06-14',
#   'status': 'FINISHED',
#   'home_id': 1431,
#   'away_name': 'Saudi Arabia',
#   'outcomes': {'half_time': '1', 'extra_time': None, 'full_time': '1'},
#   'events': 'https://livescore-api.com/api-client/scores/events.json?id=94397&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&key=sAyccMI0kNtc6o2t',
#   'ht_score': '2 - 0',
#   'score': '5 - 0',
#   'scheduled': None,
#   'et_score': '',
#   'last_changed': '2018-06-14 17:00:07',
#   'fixture_id': 0,
#   'home_name': 'Russia',
#   'competition_id': 362,
#   'added': '2018-06-14 14:55:04',
#   'location': '',
#   'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?team1_id=1431&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&key=sAyccMI0kNtc6o2t&team2_id=1432',
#   'away_id': 1432,
#   'id': 94397,
#   'ft_score': '5 - 0',
#   'time': 'FT'},
#  {'competition_name': 'FIFA World Cup',
#   'league_id': 793,
#   'date': '2018-06-15',
# ...

# %%
history_list = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=362&from=2010-01-01')
len(history_list)
# Out:
# 3

# %%
list_history=[]
for df in history_list:
    list_history.append(pd.DataFrame(df))

# %%
df_history = pd.concat(list_history, axis=0)
df_history
# Out:
#    competition_name  league_id        date    status  home_id     away_name  \
# 0    FIFA World Cup        793  2018-06-14  FINISHED     1431  Saudi Arabia
# 1    FIFA World Cup        793  2018-06-15  FINISHED      215       Uruguay
# 2    FIFA World Cup        794  2018-06-15  FINISHED     1435          Iran
# 3    FIFA World Cup        794  2018-06-15  FINISHED     1437         Spain
# 4    FIFA World Cup        795  2018-06-16  FINISHED     1439     Australia
# ..              ...        ...         ...       ...      ...           ...
# 29   FIFA World Cup        802  2018-07-08  FINISHED     1431     Croatia *
# 0    FIFA World Cup        803  2018-07-11  FINISHED     1439       Belgium
# 1    FIFA World Cup        803  2018-07-11  FINISHED      211       England
# 2    FIFA World Cup        804  2018-07-14  FINISHED     1453       England
# 3    FIFA World Cup        805  2018-07-15  FINISHED     1439       Croatia
#
#                                              outcomes  \
# ...

# %%
outcomes = df_history['outcomes'].apply(pd.Series)

# %%
df_history_wc = pd.concat([df_history, outcomes], axis=1)
df_history_wc
# Out:
#    competition_name  league_id        date    status  home_id     away_name  \
# 0    FIFA World Cup        793  2018-06-14  FINISHED     1431  Saudi Arabia
# 1    FIFA World Cup        793  2018-06-15  FINISHED      215       Uruguay
# 2    FIFA World Cup        794  2018-06-15  FINISHED     1435          Iran
# 3    FIFA World Cup        794  2018-06-15  FINISHED     1437         Spain
# 4    FIFA World Cup        795  2018-06-16  FINISHED     1439     Australia
# ..              ...        ...         ...       ...      ...           ...
# 29   FIFA World Cup        802  2018-07-08  FINISHED     1431     Croatia *
# 0    FIFA World Cup        803  2018-07-11  FINISHED     1439       Belgium
# 1    FIFA World Cup        803  2018-07-11  FINISHED      211       England
# 2    FIFA World Cup        804  2018-07-14  FINISHED     1453       England
# 3    FIFA World Cup        805  2018-07-15  FINISHED     1439       Croatia
#
#                                              outcomes  \
# ...

# %% [markdown]
# ## Get Friendlies history

# %%
history_list2 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list2.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=371&from=2010-01-01')
len(history_list2)
# Out:
# 38

# %%
list_history2=[]
for df in history_list2:
    list_history2.append(pd.DataFrame(df))
list_history2
# Out:
# [   competition_name  league_id        date    status  home_id  \
#  0        Friendlies        192  2017-01-13  FINISHED     1648
#  1        Friendlies        192  2017-01-14  FINISHED     1432
#  2        Friendlies        192  2017-01-15  FINISHED     1444
#  3        Friendlies        192  2017-01-17  FINISHED     1427
#  4        Friendlies        192  2017-01-22  FINISHED     1683
#  5        Friendlies        192  2017-01-23  FINISHED     1776
#  6        Friendlies        192  2017-01-25  FINISHED     2682
#  7        Friendlies        192  2017-01-26  FINISHED     1448
#  8        Friendlies        192  2017-01-29  FINISHED     1849
#  9        Friendlies        192  2017-02-04  FINISHED     1849
#  10       Friendlies        192  2017-02-09  FINISHED     1450
#  11       Friendlies        192  2017-02-17  FINISHED     2697
#  12       Friendlies        192  2017-02-22  FINISHED     1522
#  13       Friendlies        192  2017-02-23  FINISHED     1847
# ...

# %%
df_history_friend = pd.concat(list_history2, axis=0)
df_history_friend
# Out:
#    competition_name  league_id        date    status  home_id     away_name  \
# 0        Friendlies        192  2017-01-13  FINISHED     1648       Finland
# 1        Friendlies        192  2017-01-14  FINISHED     1432      Cambodia
# 2        Friendlies        192  2017-01-15  FINISHED     1444         Chile
# 3        Friendlies        192  2017-01-17  FINISHED     1427       Moldova
# 4        Friendlies        192  2017-01-22  FINISHED     1683        Canada
# ..              ...        ...         ...       ...      ...           ...
# 27       Friendlies          0  2022-03-29  FINISHED     2623    Kyrgyzstan
# 28       Friendlies          0  2022-03-29  FINISHED      212  Sierra Leone
# 29       Friendlies          0  2022-03-29  FINISHED     1776        Uganda
# 0        Friendlies          0  2022-03-29  FINISHED     2722         Benin
# 1        Friendlies          0  2022-03-29  FINISHED     3753        Guyana
#
#                                              outcomes  \
# ...

# %%
outcomes2 = df_history_friend['outcomes'].apply(pd.Series)

df_history_fr = pd.concat([df_history_friend, outcomes2], axis=1)
df_history_fr
# Out:
#    competition_name  league_id        date    status  home_id     away_name  \
# 0        Friendlies        192  2017-01-13  FINISHED     1648       Finland
# 1        Friendlies        192  2017-01-14  FINISHED     1432      Cambodia
# 2        Friendlies        192  2017-01-15  FINISHED     1444         Chile
# 3        Friendlies        192  2017-01-17  FINISHED     1427       Moldova
# 4        Friendlies        192  2017-01-22  FINISHED     1683        Canada
# ..              ...        ...         ...       ...      ...           ...
# 27       Friendlies          0  2022-03-29  FINISHED     2623    Kyrgyzstan
# 28       Friendlies          0  2022-03-29  FINISHED      212  Sierra Leone
# 29       Friendlies          0  2022-03-29  FINISHED     1776        Uganda
# 0        Friendlies          0  2022-03-29  FINISHED     2722         Benin
# 1        Friendlies          0  2022-03-29  FINISHED     3753        Guyana
#
#                                              outcomes  \
# ...

# %% [markdown]
# ## Get Continents International competiitions history

# %%
#UEFA
history_list3 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list3.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=387&from=2010-01-01')

list_history3=[]
for df in history_list3:
    list_history3.append(pd.DataFrame(df))

    
df_history_uefa = pd.concat(list_history3, axis=0)


outcomes3 = df_history_uefa['outcomes'].apply(pd.Series)

df_history_uefa1 = pd.concat([df_history_uefa, outcomes3], axis=1)
df_history_uefa1
# Out:
#    competition_name  league_id  has_lineups  \
# 0         UEFA EURO          0         True
# 1         UEFA EURO          0         True
# 2         UEFA EURO          0         True
# 3         UEFA EURO          0         True
# 4         UEFA EURO          0         True
# 5         UEFA EURO          0         True
# 6         UEFA EURO          0         True
# 7         UEFA EURO          0         True
# 8         UEFA EURO          0         True
# 9         UEFA EURO          0         True
# 10        UEFA EURO          0         True
# 11        UEFA EURO          0         True
# 12        UEFA EURO          0         True
# 13        UEFA EURO          0         True
# 14        UEFA EURO          0         True
# 15        UEFA EURO          0         True
# 16        UEFA EURO          0         True
# 17        UEFA EURO          0         True
# 18        UEFA EURO          0         True
# 19        UEFA EURO          0         True
# ...

# %%
#Copa America
history_list3 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list3.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=271&from=2010-01-01')

list_history3=[]
for df in history_list3:
    list_history3.append(pd.DataFrame(df))

    
df_history_copa = pd.concat(list_history3, axis=0)


outcomes3 = df_history_copa['outcomes'].apply(pd.Series)

df_history_copa_america = pd.concat([df_history_copa, outcomes3], axis=1)
df_history_copa_america
# Out:
#    competition_name has_lineups  league_id        date    status  home_id  \
# 0      Copa America       False        962  2019-06-15  FINISHED     1448
# 1      Copa America       False        962  2019-06-15  FINISHED     1850
# 2      Copa America         NaN        961  2019-06-15  FINISHED     1443
# 3      Copa America         NaN        961  2019-06-16  FINISHED     4040
# 4      Copa America       False        960  2019-06-16  FINISHED     1434
# 5      Copa America         NaN        960  2019-06-17  FINISHED     1458
# 6      Copa America       False        962  2019-06-18  FINISHED     1728
# 7      Copa America       False        962  2019-06-19  FINISHED     1448
# 8      Copa America         NaN        961  2019-06-19  FINISHED     1457
# 9      Copa America         NaN        961  2019-06-20  FINISHED     1443
# 10     Copa America         NaN        960  2019-06-20  FINISHED     1434
# 11     Copa America       False        960  2019-06-21  FINISHED     1847
# ...

# %%
#Africa Cup of Nations
history_list3 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list3.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=227&from=2010-01-01')

list_history3=[]
for df in history_list3:
    list_history3.append(pd.DataFrame(df))

    
df_history_afr = pd.concat(list_history3, axis=0)


outcomes3 = df_history_afr['outcomes'].apply(pd.Series)

df_history_africa = pd.concat([df_history_afr, outcomes3], axis=1)
df_history_africa
# Out:
#          competition_name  league_id        date    status  home_id  \
# 0   Africa Cup of Nations        347  2017-01-14  FINISHED     1546
# 1   Africa Cup of Nations        347  2017-01-14  FINISHED     1530
# 2   Africa Cup of Nations        348  2017-01-15  FINISHED     1528
# 3   Africa Cup of Nations        348  2017-01-15  FINISHED     1455
# 4   Africa Cup of Nations        349  2017-01-16  FINISHED     1628
# ..                    ...        ...         ...       ...      ...
# 23  Africa Cup of Nations          0  2022-03-23  FINISHED     2766
# 24  Africa Cup of Nations          0  2022-03-23  FINISHED     4992
# 25  Africa Cup of Nations          0  2022-03-23  FINISHED     4993
# 26  Africa Cup of Nations          0  2022-03-27  FINISHED     1615
# 27  Africa Cup of Nations          0  2022-03-27  FINISHED     1607
#
#         away_name                                           outcomes  \
# 0   Guinea-Bissau  {'half_time': 'X', 'extra_time': 'X', 'full_ti...
# ...

# %%
#Asian Cup
history_list3 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list3.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=240&from=2010-01-01')

list_history3=[]
for df in history_list3:
    list_history3.append(pd.DataFrame(df))

    
df_history_asia = pd.concat(list_history3, axis=0)


outcomes3 = df_history_asia['outcomes'].apply(pd.Series)

df_history_asia_cup = pd.concat([df_history_asia, outcomes3], axis=1)
df_history_asia_cup
# Out:
#    competition_name  league_id        date      id  home_id     away_name  \
# 0         Asian Cup        925  2019-01-05  122532     1797       Bahrain
# 1         Asian Cup        926  2019-01-06  122568     1440        Jordan
# 2         Asian Cup        925  2019-01-06  122581     2688         India
# 3         Asian Cup        926  2019-01-06  122601     1695     Palestine
# 4         Asian Cup        927  2019-01-07  122627     1717    Kyrgyzstan
# 5         Asian Cup        927  2019-01-07  122629     1452   Philippines
# 6         Asian Cup        928  2019-01-07  122630     1436         Yemen
# 7         Asian Cup        928  2019-01-08  122651     1715       Vietnam
# 8         Asian Cup        929  2019-01-08  122659     1432   North Korea
# 9         Asian Cup        930  2019-01-09  122692     1458  Turkmenistan
# 10        Asian Cup        930  2019-01-09  122699     1776          Oman
# 11        Asian Cup        929  2019-01-09  122709     1427       Lebanon
# ...

# %%
#Gold Cup
history_list3 = []

def get_data(link):
    with urlopen(link) as response:
        his = response.read()
        history = json.loads(his)
        history_list3.append(history.get('data')['match'])
        if history.get('data')['next_page'] != False:
            get_data(history.get('data')['next_page'])
get_data('http://livescore-api.com/api-client/scores/history.json?key=sAyccMI0kNtc6o2t&secret=qDty37iEy2ENubtXL2aYOTY9GslMQogh&competition_id=266&from=2010-01-01')

list_history3=[]
for df in history_list3:
    list_history3.append(pd.DataFrame(df))

    
df_history_gold = pd.concat(list_history3, axis=0)


outcomes3 = df_history_gold['outcomes'].apply(pd.Series)

df_history_gold_cup = pd.concat([df_history_gold, outcomes3], axis=1)
df_history_gold_cup
# Out:
#    competition_name  league_id        date    status  home_id      away_name  \
# 0          Gold Cup        676  2017-07-10  FINISHED        0    El Salvador
# 1          Gold Cup        670  2017-07-12  FINISHED        0         Canada
# 2          Gold Cup        670  2017-07-12  FINISHED        0  French Guiana
# 3          Gold Cup        674  2017-07-13  FINISHED        0      Nicaragua
# 4          Gold Cup        674  2017-07-13  FINISHED        0     Martinique
# ..              ...        ...         ...       ...      ...            ...
# 23         Gold Cup          0  2021-07-25  FINISHED     1446         Canada
# 24         Gold Cup          0  2021-07-26  FINISHED     1849        Jamaica
# 25         Gold Cup          0  2021-07-29  FINISHED     1427            USA
# 26         Gold Cup          0  2021-07-30  FINISHED     1450         Canada
# 27         Gold Cup          0  2021-08-02  FINISHED     1849         Mexico
#
# ...

# %%
df_all_history = pd.concat([df_history_wc,df_history_fr,df_history_uefa1,df_history_copa_america,df_history_africa,
                          df_history_asia_cup,df_history_gold_cup],ignore_index=True)
df_all_history
# Out:
#      competition_name  league_id        date    status  home_id     away_name  \
# 0      FIFA World Cup        793  2018-06-14  FINISHED     1431  Saudi Arabia
# 1      FIFA World Cup        793  2018-06-15  FINISHED      215       Uruguay
# 2      FIFA World Cup        794  2018-06-15  FINISHED     1435          Iran
# 3      FIFA World Cup        794  2018-06-15  FINISHED     1437         Spain
# 4      FIFA World Cup        795  2018-06-16  FINISHED     1439     Australia
# ...               ...        ...         ...       ...      ...           ...
# 1592         Gold Cup          0  2021-07-25  FINISHED     1446        Canada
# 1593         Gold Cup          0  2021-07-26  FINISHED     1849       Jamaica
# 1594         Gold Cup          0  2021-07-29  FINISHED     1427           USA
# 1595         Gold Cup          0  2021-07-30  FINISHED     1450        Canada
# 1596         Gold Cup          0  2021-08-02  FINISHED     1849        Mexico
#
# ...

# %%
df_all_history.drop('outcomes',axis=1,inplace=True)

# %%
df_all_history.to_csv('WC_history.csv')

# %%
df_all_history = pd.read_csv('WC_history.csv',index_col=[0])

# %%
df_all_history['home_score'] = df_all_history['score'].str[0]
df_all_history['away_score'] = df_all_history['score'].str[-1]

# %%
df_all_history = df_all_history[df_all_history['home_score'] != '?']

# %%
df_all_history['home_score'] = pd.to_numeric(df_all_history['home_score'])
df_all_history['away_score'] = pd.to_numeric(df_all_history['away_score'])

# %%
df_all_history.rename(columns={'away_name':'away_team','home_name':'home_team'},inplace=True)

# %%
df_all_history = df_all_history[['competition_name','date','home_team','away_team','home_score','away_score','score','id']]

# %%
# create a list of our conditions
conditions = [
    (df_all_history['home_score'] > df_all_history['away_score']),
    (df_all_history['home_score'] < df_all_history['away_score'])
    ]

# create a list of the values we want to assign for each condition
values = [1, 2]

# create a new column and use np.select to assign values to it using our lists as arguments
df_all_history['match_result'] = np.select(conditions, values,0)
df_all_history
# Out:
#      competition_name        date   home_team     away_team  home_score  \
# 0      FIFA World Cup  2018-06-14      Russia  Saudi Arabia           5
# 1      FIFA World Cup  2018-06-15       Egypt       Uruguay           0
# 2      FIFA World Cup  2018-06-15     Morocco          Iran           0
# 3      FIFA World Cup  2018-06-15    Portugal         Spain           3
# 4      FIFA World Cup  2018-06-16      France     Australia           2
# ...               ...         ...         ...           ...         ...
# 1592         Gold Cup  2021-07-25  Costa Rica        Canada           0
# 1593         Gold Cup  2021-07-26         USA       Jamaica           1
# 1594         Gold Cup  2021-07-29       Qatar           USA           0
# 1595         Gold Cup  2021-07-30      Mexico        Canada           2
# 1596         Gold Cup  2021-08-02         USA        Mexico           1
#
#       away_score  score      id  match_result
# 0              0  5 - 0   94397             1
# ...

# %%
df_all_history.to_csv('Model 2/Data/from_2017_matches_history.csv')
